# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Capstone_Mobile.csv')

# %%
df
# Out:
#        Taken_product  Yearly_avg_view_on_travel_page  \
# 0                  1                        0.427409
# 1                  0                        1.390536
# 2                  1                       -0.054154
# 3                  0                       -0.535717
# 4                  0                       -1.258062
# ...              ...                             ...
# 10647              0                       -0.535717
# 10648              0                       -1.129645
# 10649              0                        0.395305
# 10650              0                       -1.065437
# 10651              0                       -0.166519
#
#        total_likes_on_outstation_checkin_given  \
# 0                                     0.766137
# 1                                    -1.344218
# 2                                     1.461041
# 3                                     1.509761
# 4                                    -0.544181
# ...                                        ...
# 10647                                -1.223114
# 10648                                 0.935815
# 10649                                -0.483738
# 10650                                -1.626004
# 10651                                -0.446008
#
#        yearly_avg_Outstation_checkins  member_in_family  \
# 0                           -0.831881         -0.910174
# 1                           -0.831881         -1.940858
# 2                           -0.831881         -0.910174
# 3                           -0.831881          1.151193
# 4                           -0.831881         -1.940858
# ...                               ...               ...
# 10647                       -0.369485          0.120509
# 10648                       -0.369485          0.120509
# 10649                       -0.253886         -1.940858
# 10650                       -0.485084          0.120509
# 10651                       -0.022687          0.120509
#
#        Yearly_avg_comment_on_travel_page  \
# 0                               0.946332
# 1                              -0.671720
# 2                               0.848268
# 3                              -0.916880
# 4                              -1.652358
# ...                                  ...
# 10647                           1.191492
# 10648                          -1.063975
# 10649                          -0.965912
# 10650                           1.387619
# 10651                           1.436651
#
#        total_likes_on_outofstation_checkin_received  \
# 0                                         -0.108701
# 1                                         -0.299584
# 2                                         -0.962697
# 3                                         -0.790836
# 4                                         -0.667194
# ...                                             ...
# 10647                                      0.773828
# 10648                                     -0.765400
# 10649                                      0.786656
# 10650                                     -0.062252
# 10651                                     -0.445566
#
#        week_since_last_outstation_checkin  following_company_page  \
# 0                                1.833319                       1
# 1                               -0.842262                       0
# 2                                1.068868                       1
# 3                               -0.842262                       1
# 4                                2.215545                       0
# ...                                   ...                     ...
# 10647                           -0.842262                       0
# 10648                           -0.460036                       0
# 10649                            0.304416                       0
# 10650                           -0.077810                       1
# 10651                           -0.460036                       0
#
#        montly_avg_comment_on_company_page  ...  \
# 0                               -1.562119  ...
# 1                                0.046226  ...
# 2                               -1.123479  ...
# 3                               -1.562119  ...
# 4                               -1.562119  ...
# ...                                   ...  ...
# 10647                            0.777292  ...
# 10648                            1.362145  ...
# 10649                            1.069719  ...
# 10650                            1.946998  ...
# 10651                            0.923505  ...
#
#        preferred_location_type_Big Cities  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 10647                                   0
# 10648                                   0
# 10649                                   0
# 10650                                   0
# 10651                                   0
#
#        preferred_location_type_Entertainment  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ...                                      ...
# 10647                                      0
# 10648                                      0
# 10649                                      0
# 10650                                      0
# 10651                                      0
#
#        preferred_location_type_Financial  \
# 0                                      1
# 1                                      1
# 2                                      0
# 3                                      1
# 4                                      0
# ...                                  ...
# 10647                                  0
# 10648                                  0
# 10649                                  0
# 10650                                  0
# 10651                                  0
#
#        preferred_location_type_Hill Stations  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ...                                      ...
# 10647                                      0
# 10648                                      0
# 10649                                      0
# 10650                                      0
# 10651                                      0
#
#        preferred_location_type_Historical site  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ...                                        ...
# 10647                                        1
# 10648                                        0
# 10649                                        1
# 10650                                        0
# 10651                                        1
#
#        preferred_location_type_Medical  preferred_location_type_Other  \
# 0                                    0                              0
# 1                                    0                              0
# 2                                    0                              1
# 3                                    0                              0
# 4                                    1                              0
# ...                                ...                            ...
# 10647                                0                              0
# 10648                                0                              1
# 10649                                0                              0
# 10650                                0                              0
# 10651                                0                              0
#
#        preferred_location_type_Social media  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
# ...                                     ...
# 10647                                     0
# 10648                                     0
# 10649                                     0
# 10650                                     0
# 10651                                     0
#
#        preferred_location_type_Tour and Travel  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ...                                        ...
# 10647                                        0
# 10648                                        0
# 10649                                        0
# 10650                                        0
# 10651                                        0
#
#        preferred_location_type_Trekking
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
# ...                                 ...
# 10647                                 0
# 10648                                 0
# 10649                                 0
# 10650                                 0
# 10651                                 0
#
# [10652 rows x 24 columns]

# %% [markdown]
# # Split the predictors and target variables

# %%
X=df.drop('Taken_product', axis=1)
y=df['Taken_product']

# %% [markdown]
# # Split into test train and split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0,stratify=y)

# %%
X_train.head()
# Out:
#       Yearly_avg_view_on_travel_page  total_likes_on_outstation_checkin_given  \
# 1533                       -0.150467                                 1.589549
# 6304                       -1.450688                                -0.282264
# 7575                       -0.214675                                 1.384920
# 7307                       -0.969124                                 0.805333
# 4061                       -0.134415                                 0.209774
#
#       yearly_avg_Outstation_checkins  member_in_family  \
# 1533                        1.942498          0.120509
# 6304                       -0.600683         -0.910174
# 7575                        2.173697         -1.940858
# 7307                       -0.022687         -0.910174
# 4061                       -0.831881          1.151193
#
#       Yearly_avg_comment_on_travel_page  \
# 1533                           1.191492
# 6304                          -0.279465
# 7575                          -0.916880
# 7307                          -0.132369
# 4061                           0.505045
#
#       total_likes_on_outofstation_checkin_received  \
# 1533                                      0.254927
# 6304                                     -0.419909
# 7575                                     -0.865818
# 7307                                     -0.701256
# 4061                                      0.084394
#
#       week_since_last_outstation_checkin  following_company_page  \
# 1533                            1.451093                       0
# 6304                            2.215545                       0
# 7575                           -0.842262                       0
# 7307                           -0.842262                       0
# 4061                            1.833319                       0
#
#       montly_avg_comment_on_company_page  working_flag  ...  \
# 1533                           -1.562119             0  ...
# 6304                           -0.392413             0  ...
# 7575                           -0.099987             0  ...
# 7307                            0.777292             1  ...
# 4061                           -0.831053             0  ...
#
#       preferred_location_type_Big Cities  \
# 1533                                   0
# 6304                                   0
# 7575                                   0
# 7307                                   0
# 4061                                   0
#
#       preferred_location_type_Entertainment  \
# 1533                                      0
# 6304                                      0
# 7575                                      0
# 7307                                      0
# 4061                                      0
#
#       preferred_location_type_Financial  \
# 1533                                  1
# 6304                                  0
# 7575                                  0
# 7307                                  0
# 4061                                  1
#
#       preferred_location_type_Hill Stations  \
# 1533                                      0
# 6304                                      0
# 7575                                      0
# 7307                                      0
# 4061                                      0
#
#       preferred_location_type_Historical site  \
# 1533                                        0
# 6304                                        0
# 7575                                        1
# 7307                                        0
# 4061                                        0
#
#       preferred_location_type_Medical  preferred_location_type_Other  \
# 1533                                0                              0
# 6304                                0                              0
# 7575                                0                              0
# 7307                                0                              0
# 4061                                0                              0
#
#       preferred_location_type_Social media  \
# 1533                                     0
# 6304                                     0
# 7575                                     0
# 7307                                     0
# 4061                                     0
#
#       preferred_location_type_Tour and Travel  \
# 1533                                        0
# 6304                                        0
# 7575                                        0
# 7307                                        0
# 4061                                        0
#
#       preferred_location_type_Trekking
# 1533                                 0
# 6304                                 0
# 7575                                 0
# 7307                                 0
# 4061                                 0
#
# [5 rows x 23 columns]

# %%
X_test.head()
# Out:
#       Yearly_avg_view_on_travel_page  total_likes_on_outstation_checkin_given  \
# 2472                       -0.294936                                -1.546792
# 5604                        1.165806                                 1.084760
# 382                        -1.370427                                -0.585208
# 9532                       -0.696238                                -1.317184
# 9492                       -0.086258                                 0.128964
#
#       yearly_avg_Outstation_checkins  member_in_family  \
# 2472                        1.133304         -0.910174
# 5604                       -0.831881          1.151193
# 382                        -0.831881         -1.940858
# 9532                       -0.716282          0.120509
# 9492                       -0.369485          1.151193
#
#       Yearly_avg_comment_on_travel_page  \
# 2472                          -0.720752
# 5604                          -1.063975
# 382                           -0.083338
# 9532                           1.632779
# 9492                           1.289555
#
#       total_likes_on_outofstation_checkin_received  \
# 2472                                      0.636472
# 5604                                      2.110450
# 382                                      -0.748147
# 9532                                     -0.505950
# 9492                                     -0.664097
#
#       week_since_last_outstation_checkin  following_company_page  \
# 2472                           -0.460036                       0
# 5604                            1.833319                       0
# 382                            -1.224488                       0
# 9532                           -0.460036                       0
# 9492                            2.979997                       1
#
#       montly_avg_comment_on_company_page  working_flag  ...  \
# 2472                           -1.562119             0  ...
# 5604                           -0.099987             0  ...
# 382                            -0.099987             1  ...
# 9532                            0.923505             0  ...
# 9492                            1.069719             0  ...
#
#       preferred_location_type_Big Cities  \
# 2472                                   0
# 5604                                   0
# 382                                    0
# 9532                                   0
# 9492                                   0
#
#       preferred_location_type_Entertainment  \
# 2472                                      0
# 5604                                      0
# 382                                       1
# 9532                                      0
# 9492                                      0
#
#       preferred_location_type_Financial  \
# 2472                                  1
# 5604                                  1
# 382                                   0
# 9532                                  0
# 9492                                  0
#
#       preferred_location_type_Hill Stations  \
# 2472                                      0
# 5604                                      0
# 382                                       0
# 9532                                      0
# 9492                                      0
#
#       preferred_location_type_Historical site  \
# 2472                                        0
# 5604                                        0
# 382                                         0
# 9532                                        0
# 9492                                        0
#
#       preferred_location_type_Medical  preferred_location_type_Other  \
# 2472                                0                              0
# 5604                                0                              0
# 382                                 0                              0
# 9532                                0                              0
# 9492                                0                              0
#
#       preferred_location_type_Social media  \
# 2472                                     0
# 5604                                     0
# 382                                      0
# 9532                                     0
# 9492                                     0
#
#       preferred_location_type_Tour and Travel  \
# 2472                                        0
# 5604                                        0
# 382                                         0
# 9532                                        0
# 9492                                        0
#
#       preferred_location_type_Trekking
# 2472                                 0
# 5604                                 0
# 382                                  0
# 9532                                 0
# 9492                                 0
#
# [5 rows x 23 columns]

# %%
y_train.head()
# Out:
# 1533    0
# 6304    1
# 7575    0
# 7307    0
# 4061    0
# Name: Taken_product, dtype: int64

# %%
y_test.head()
# Out:
# 2472    0
# 5604    0
# 382     1
# 9532    0
# 9492    0
# Name: Taken_product, dtype: int64

# %%
print(f'In X train, the number of rows  = {X_train.shape[0]} and number of columns = {X_train.shape[1]}')
print(f'In X test, the number of rows  = {X_test.shape[0]} and number of columns = {X_test.shape[1]}')
print(f'In y train, the number of rows  = {y_train.__len__()} ')
print(f'In y train, the number of rows  = {y_test.__len__()} ')
# Out:
# In X train, the number of rows  = 7456 and number of columns = 23
# In X test, the number of rows  = 3196 and number of columns = 23
# In y train, the number of rows  = 7456
# In y train, the number of rows  = 3196

# %%
sns.set(font_scale=1.5)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression

# %%
model_log = LogisticRegression()
model_log.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Predicting on Training and Test dataset
ytrain_predict_log = model_log.predict(X_train)
ytest_predict_log = model_log.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_log.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_log.score(X_test, y_test))
print("----------------------------------------------------\n")
# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict_log))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict_log))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict_log))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict_log))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Logistic Regression")
probs = model_log.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.870574034334764
# Accuracy of the model on Testing data :  0.8692115143929913
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      6322
#            1       0.77      0.21      0.33      1134
#
#     accuracy                           0.87      7456
#    macro avg       0.82      0.60      0.63      7456
# weighted avg       0.86      0.87      0.84      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      2710
#            1       0.74      0.22      0.34       486
#
#     accuracy                           0.87      3196
#    macro avg       0.81      0.60      0.63      3196
# weighted avg       0.85      0.87      0.84      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6248   74]
#  [ 891  243]]
#
# Confusion matrix on test data
# [[2672   38]
#  [ 380  106]]
# ----------------------------------------------------
#
# AUC: 0.790

# %%
# predict probabilities
plt.title("ROC Curve for testing set of Logistic Regression")
probs = model_log.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=16)
# Out:
# AUC: 0.799

# %% [markdown]
# # Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lda = LinearDiscriminantAnalysis()
model_lda =lda.fit(X_train,y_train)

# %%
# Predicting on Training and Test dataset
ytrain_predict_lda = model_lda.predict(X_train)
ytest_predict_lda = model_lda.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_lda.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_lda.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict_lda))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict_lda))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict_lda))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict_lda))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of LDA")
probs = model_lda.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.8685622317596566
# Accuracy of the model on Testing data :  0.8701501877346683
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      6322
#            1       0.70      0.24      0.36      1134
#
#     accuracy                           0.87      7456
#    macro avg       0.79      0.61      0.64      7456
# weighted avg       0.85      0.87      0.84      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      2710
#            1       0.70      0.26      0.37       486
#
#     accuracy                           0.87      3196
#    macro avg       0.79      0.62      0.65      3196
# weighted avg       0.85      0.87      0.84      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6205  117]
#  [ 863  271]]
#
# Confusion matrix on test data
# [[2657   53]
#  [ 362  124]]
# ----------------------------------------------------
#
# AUC: 0.785

# %%
# predict probabilities
plt.title("ROC Curve for testing set of LDA")
probs = model_lda.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=16)
# Out:
# AUC: 0.795

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model_nb = GaussianNB()
model_nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Predicting on Training and Test dataset
ytrain_predict_nb = model_nb.predict(X_train)
ytest_predict_nb = model_nb.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_nb.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_nb.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict_nb))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict_nb))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict_nb))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict_nb))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Naive Bayes")
probs = model_nb.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.7801770386266095
# Accuracy of the model on Testing data :  0.7794117647058824
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      6322
#            1       0.28      0.29      0.28      1134
#
#     accuracy                           0.78      7456
#    macro avg       0.58      0.58      0.58      7456
# weighted avg       0.78      0.78      0.78      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      2710
#            1       0.28      0.29      0.29       486
#
#     accuracy                           0.78      3196
#    macro avg       0.58      0.58      0.58      3196
# weighted avg       0.78      0.78      0.78      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[5493  829]
#  [ 810  324]]
#
# Confusion matrix on test data
# [[2350  360]
#  [ 345  141]]
# ----------------------------------------------------
#
# AUC: 0.719

# %%
# predict probabilities
plt.title("ROC Curve for testing set of Naive Bayes")
probs = model_nb.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=16)
# Out:
# AUC: 0.719

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn= KNeighborsClassifier()
model_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predicting on Training and Test dataset
ytrain_predict_knn = model_knn.predict(X_train)
ytest_predict_knn = model_knn.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_knn.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_knn.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict_knn))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict_knn))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict_knn))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict_knn))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of KNN")
probs = model_knn.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.9761266094420601
# Accuracy of the model on Testing data :  0.9518147684605757
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      6322
#            1       0.96      0.88      0.92      1134
#
#     accuracy                           0.98      7456
#    macro avg       0.97      0.94      0.95      7456
# weighted avg       0.98      0.98      0.98      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      2710
#            1       0.93      0.74      0.82       486
#
#     accuracy                           0.95      3196
#    macro avg       0.94      0.87      0.90      3196
# weighted avg       0.95      0.95      0.95      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6284   38]
#  [ 140  994]]
#
# Confusion matrix on test data
# [[2681   29]
#  [ 125  361]]
# ----------------------------------------------------
#
# AUC: 0.996

# %%
# predict probabilities
plt.title("ROC Curve for testing set of KNN")
probs = model_knn.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=16)
# Out:
# AUC: 0.981

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model_dt = DecisionTreeClassifier()
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Predicting on Training and Test dataset
ytrain_predict_dt = model_dt.predict(X_train)
ytest_predict_dt = model_dt.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_dt.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_dt.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict_dt))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict_dt))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict_dt))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict_dt))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Decision Tree")
probs = model_dt.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  1.0
# Accuracy of the model on Testing data :  0.9746558197747184
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6322
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      7456
#    macro avg       1.00      1.00      1.00      7456
# weighted avg       1.00      1.00      1.00      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      2710
#            1       0.93      0.91      0.92       486
#
#     accuracy                           0.97      3196
#    macro avg       0.95      0.95      0.95      3196
# weighted avg       0.97      0.97      0.97      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6322    0]
#  [   0 1134]]
#
# Confusion matrix on test data
# [[2675   35]
#  [  46  440]]
# ----------------------------------------------------
#
# AUC: 1.000

# %%
# predict probabilities
plt.title("ROC Curve for testing set of Decision Tree")
probs = model_dt.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=16)
# Out:
# AUC: 0.946

# %% [markdown]
# # Ensemble Technique

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf=RandomForestClassifier(n_estimators=100,random_state=1)
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
# Predicting on Training and Test dataset
ytrain_predict = model_rf.predict(X_train)
ytest_predict = model_rf.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_rf.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_rf.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Random Forest")
probs = model_rf.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  1.0
# Accuracy of the model on Testing data :  0.9730913642052565
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6322
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      7456
#    macro avg       1.00      1.00      1.00      7456
# weighted avg       1.00      1.00      1.00      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      2710
#            1       1.00      0.83      0.90       486
#
#     accuracy                           0.97      3196
#    macro avg       0.98      0.91      0.94      3196
# weighted avg       0.97      0.97      0.97      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6322    0]
#  [   0 1134]]
#
# Confusion matrix on test data
# [[2709    1]
#  [  85  401]]
# ----------------------------------------------------
#
# AUC: 1.000

# %%
# predict probabilities
plt.title("ROC Curve for test set of Random Forest")
probs = model_rf.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=20)
# Out:
# AUC: 0.998

# %% [markdown]
# # Ada Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier

model_adb = AdaBoostClassifier(random_state=1)
model_adb.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(random_state=1)

# %%
# Predicting on Training and Test dataset
ytrain_predict = model_adb.predict(X_train)
ytest_predict = model_adb.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_adb.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_adb.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Ada Boosting")
probs = model_adb.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.8786212446351931
# Accuracy of the model on Testing data :  0.8676470588235294
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      6322
#            1       0.72      0.33      0.45      1134
#
#     accuracy                           0.88      7456
#    macro avg       0.80      0.65      0.69      7456
# weighted avg       0.86      0.88      0.86      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.93      2710
#            1       0.65      0.28      0.39       486
#
#     accuracy                           0.87      3196
#    macro avg       0.77      0.63      0.66      3196
# weighted avg       0.85      0.87      0.84      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6175  147]
#  [ 758  376]]
#
# Confusion matrix on test data
# [[2636   74]
#  [ 349  137]]
# ----------------------------------------------------
#
# AUC: 0.852

# %%
# predict probabilities
plt.title("ROC Curve for test set of Ada Boosting")
probs = model_adb.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=20)
# Out:
# AUC: 0.823

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
model_gb = GradientBoostingClassifier(random_state=1).fit(X_train, y_train)

# %%
# Predicting on Training and Test dataset
ytrain_predict = model_gb.predict(X_train)
ytest_predict = model_gb.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_gb.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_gb.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Gradient Boosting")
probs = model_gb.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.9104077253218884
# Accuracy of the model on Testing data :  0.898936170212766
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      6322
#            1       0.93      0.44      0.60      1134
#
#     accuracy                           0.91      7456
#    macro avg       0.92      0.72      0.78      7456
# weighted avg       0.91      0.91      0.90      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      2710
#            1       0.88      0.39      0.54       486
#
#     accuracy                           0.90      3196
#    macro avg       0.89      0.69      0.74      3196
# weighted avg       0.90      0.90      0.88      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6286   36]
#  [ 632  502]]
#
# Confusion matrix on test data
# [[2683   27]
#  [ 296  190]]
# ----------------------------------------------------
#
# AUC: 0.943

# %%
# predict probabilities
plt.title("ROC Curve for test set of Gradient Boosting")
probs = model_gb.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=20)
# Out:
# AUC: 0.911

# %% [markdown]
# # Bagging

# %%
from sklearn.ensemble import BaggingClassifier
model_bag=BaggingClassifier(base_estimator=model_rf,random_state=1)
model_bag.fit(X_train, y_train)
# Out:
# BaggingClassifier(base_estimator=RandomForestClassifier(random_state=1),
#                   random_state=1)

# %%
# Predicting on Training and Test dataset
ytrain_predict_bag = model_bag.predict(X_train)
ytest_predict_bag = model_bag.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_bag.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_bag.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict_bag))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict_bag))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict_bag))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict_bag))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Bagging")
probs = model_bag.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.9949034334763949
# Accuracy of the model on Testing data :  0.9524405506883604
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6322
#            1       1.00      0.97      0.98      1134
#
#     accuracy                           0.99      7456
#    macro avg       1.00      0.98      0.99      7456
# weighted avg       0.99      0.99      0.99      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      2710
#            1       1.00      0.69      0.82       486
#
#     accuracy                           0.95      3196
#    macro avg       0.97      0.84      0.89      3196
# weighted avg       0.95      0.95      0.95      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6321    1]
#  [  37 1097]]
#
# Confusion matrix on test data
# [[2709    1]
#  [ 151  335]]
# ----------------------------------------------------
#
# AUC: 1.000

# %%
# predict probabilities
plt.title("ROC Curve for test set of Bagging")
probs = model_bag.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=20)
# Out:
# AUC: 0.995

# %% [markdown]
# # Model Tuning

# %% [markdown]
# # Tuned Logistic Regression

# %%
param_grid = {'solver' : ('newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'),
             'penalty' : ('l1', 'l2', 'elasticnet', 'none'), 'C' : (100, 10, 1.0, 0.1, 0.01)}

# %%
from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(model_log,param_grid,cv=10)
gs.fit(X_train, y_train)
gs.best_params_
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 450 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 457, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1471, in fit
#     raise ValueError(
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 464, in _check_solver
#     raise ValueError("penalty='none' is not supported for the liblinear solver")
# ValueError: penalty='none' is not supported for the liblinear solver
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.86976753        nan 0.86976753 0.86976753
#  0.86976753 0.86976753 0.86976753 0.86976753        nan        nan
#         nan        nan        nan 0.86976753 0.86990158        nan
#  0.86976753 0.86976753        nan        nan 0.86949925        nan
#  0.86949925 0.86949925 0.86976753 0.86949925 0.86949925 0.86949925
#         nan        nan        nan        nan        nan 0.86976753
#  0.86990158        nan 0.86976753 0.86976753        nan        nan
#  0.86856056        nan 0.86856056 0.86896306 0.86896306 0.86896306
#  0.86896306 0.86896306        nan        nan        nan        nan
#         nan 0.86976753 0.86990158        nan 0.86976753 0.86976753
#         nan        nan 0.86587797        nan 0.8657441  0.86493909
#  0.86493909 0.86507296 0.86493909 0.86493909        nan        nan
#         nan        nan        nan 0.86976753 0.86990158        nan
#  0.86990158 0.86976753        nan        nan 0.8532724         nan
#  0.84790795 0.85407741 0.85407741 0.85823398 0.85407741 0.85407741
#         nan        nan        nan        nan        nan 0.86976753
#  0.86990158        nan 0.86976753 0.86976753]
#   warnings.warn(
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# {'C': 100, 'penalty': 'none', 'solver': 'lbfgs'}

# %%
#Best parameters for Logistic regression :
model_log_best=LogisticRegression(penalty='none', C=100, solver='lbfgs')
model_log_best.fit(X_train,y_train)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# LogisticRegression(C=100, penalty='none')

# %%
# Predicting on Training and Test dataset
ytrain_predict_log = model_log_best.predict(X_train)
ytest_predict_log = model_log_best.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_log_best.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_log_best.score(X_test, y_test))
print("----------------------------------------------------\n")
# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict_log))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict_log))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict_log))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict_log))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Tuned Logistic Regression")
probs = model_log_best.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.8715128755364807
# Accuracy of the model on Testing data :  0.8688986232790988
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      6322
#            1       0.77      0.22      0.34      1134
#
#     accuracy                           0.87      7456
#    macro avg       0.82      0.60      0.64      7456
# weighted avg       0.86      0.87      0.84      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      2710
#            1       0.73      0.22      0.34       486
#
#     accuracy                           0.87      3196
#    macro avg       0.80      0.60      0.63      3196
# weighted avg       0.85      0.87      0.84      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6248   74]
#  [ 884  250]]
#
# Confusion matrix on test data
# [[2671   39]
#  [ 380  106]]
# ----------------------------------------------------
#
# AUC: 0.790

# %%
# predict probabilities
plt.title("ROC Curve for testing set of Tuned Logistic Regression")
probs = model_log_best.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=16)
# Out:
# AUC: 0.799

# %% [markdown]
# # Tuned LDA

# %%
param_grid = {'solver' : ('svd', 'lsqr', 'eigen'), }
gs = GridSearchCV(model_lda,param_grid,cv=10)
gs.fit(X_train, y_train)
gs.best_params_
# Out:
# {'solver': 'lsqr'}

# %%
lda = LinearDiscriminantAnalysis(solver='lsqr')
model_lda_best =lda.fit(X_train,y_train)

# %%
# Predicting on Training and Test dataset
ytrain_predict_lda = model_lda_best.predict(X_train)
ytest_predict_lda = model_lda_best.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_lda_best.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_lda_best.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict_lda))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict_lda))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict_lda))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict_lda))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Tuned LDA")
probs = model_lda_best.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.8685622317596566
# Accuracy of the model on Testing data :  0.8701501877346683
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      6322
#            1       0.70      0.24      0.36      1134
#
#     accuracy                           0.87      7456
#    macro avg       0.79      0.61      0.64      7456
# weighted avg       0.85      0.87      0.84      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      2710
#            1       0.70      0.26      0.37       486
#
#     accuracy                           0.87      3196
#    macro avg       0.79      0.62      0.65      3196
# weighted avg       0.85      0.87      0.84      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6205  117]
#  [ 863  271]]
#
# Confusion matrix on test data
# [[2657   53]
#  [ 362  124]]
# ----------------------------------------------------
#
# AUC: 0.785

# %%
# predict probabilities
plt.title("ROC Curve for testing set of Tuned LDA")
probs = model_lda_best.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=16)
# Out:
# AUC: 0.795

# %% [markdown]
# # Tuned KNN

# %%
param_grid = {'n_neighbors': list(range(1,20,2)),
             'algorithm': ('auto', 'ball_tree', 'kd_tree' , 'brute'),'weights' : ('uniform', 'distance') }
gs = GridSearchCV(model_knn,param_grid,cv=10)
gs.fit(X_train, y_train)
gs.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 1, 'weights': 'uniform'}

# %%
#Best parameters for KNN :
model_knn_best=KNeighborsClassifier(n_neighbors=1)
model_knn_best.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
# Predicting on Training and Test dataset
ytrain_predict_knn = model_knn_best.predict(X_train)
ytest_predict_knn = model_knn_best.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_knn_best.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_knn_best.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict_knn))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict_knn))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict_knn))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict_knn))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Tuned KNN")
probs = model_knn_best.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  1.0
# Accuracy of the model on Testing data :  0.9874843554443054
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6322
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      7456
#    macro avg       1.00      1.00      1.00      7456
# weighted avg       1.00      1.00      1.00      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2710
#            1       0.96      0.96      0.96       486
#
#     accuracy                           0.99      3196
#    macro avg       0.98      0.97      0.98      3196
# weighted avg       0.99      0.99      0.99      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6322    0]
#  [   0 1134]]
#
# Confusion matrix on test data
# [[2691   19]
#  [  21  465]]
# ----------------------------------------------------
#
# AUC: 1.000

# %%
# predict probabilities
plt.title("ROC Curve for testing set of Tuned KNN")
probs = model_knn_best.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=16)
# Out:
# AUC: 0.975

# %% [markdown]
# # Tuned Random Forest

# %%
param_grid = {
    'n_estimators': [100, 50],
    'max_depth': [10, 5],
    'min_samples_split': [15,25],
    'min_samples_leaf': [15, 25],
}

gs = GridSearchCV(model_rf,param_grid,cv=10)
gs.fit(X_train, y_train)
gs.best_params_
# Out:
# {'max_depth': 10,
#  'min_samples_leaf': 15,
#  'min_samples_split': 15,
#  'n_estimators': 50}

# %%
model_rf_best=RandomForestClassifier(n_estimators=50,max_depth=10,min_samples_leaf=15,min_samples_split=15).fit(X_train,y_train)

# %%
# Predicting on Training and Test dataset
ytrain_predict = model_rf_best.predict(X_train)
ytest_predict = model_rf_best.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_rf_best.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_rf_best.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Tuned Random Forest")
probs = model_rf_best.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.8837178111587983
# Accuracy of the model on Testing data :  0.8714017521902377
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      6322
#            1       0.96      0.25      0.39      1134
#
#     accuracy                           0.88      7456
#    macro avg       0.92      0.62      0.66      7456
# weighted avg       0.89      0.88      0.85      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      2710
#            1       0.90      0.17      0.29       486
#
#     accuracy                           0.87      3196
#    macro avg       0.89      0.58      0.61      3196
# weighted avg       0.88      0.87      0.83      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6310   12]
#  [ 855  279]]
#
# Confusion matrix on test data
# [[2701    9]
#  [ 402   84]]
# ----------------------------------------------------
#
# AUC: 0.967

# %%
# predict probabilities
plt.title("ROC Curve for test set of Tuned Random Forest")
probs = model_rf_best.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=20)
# Out:
# AUC: 0.929

# %% [markdown]
# # Tuned Bagging

# %%
param_grid = {'n_estimators' : [10,20,30] }
gs = GridSearchCV(model_bag,param_grid,cv=10)
gs.fit(X_train, y_train)
gs.best_params_
# Out:
# {'n_estimators': 30}

# %%
model_bag_best=BaggingClassifier(base_estimator=model_rf_best,n_estimators=30,random_state=1)
model_bag_best.fit(X_train, y_train)
# Out:
# BaggingClassifier(base_estimator=RandomForestClassifier(max_depth=10,
#                                                         min_samples_leaf=15,
#                                                         min_samples_split=15,
#                                                         n_estimators=50),
#                   n_estimators=30, random_state=1)

# %%
# Predicting on Training and Test dataset
ytrain_predict_bag = model_bag_best.predict(X_train)
ytest_predict_bag = model_bag_best.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_bag_best.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_bag_best.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict_bag))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict_bag))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict_bag))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict_bag))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Tuned Bagging")
probs = model_bag_best.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.8732564377682404
# Accuracy of the model on Testing data :  0.8642052565707133
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      6322
#            1       0.93      0.18      0.30      1134
#
#     accuracy                           0.87      7456
#    macro avg       0.90      0.59      0.62      7456
# weighted avg       0.88      0.87      0.83      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      2710
#            1       0.85      0.13      0.22       486
#
#     accuracy                           0.86      3196
#    macro avg       0.86      0.56      0.58      3196
# weighted avg       0.86      0.86      0.82      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6307   15]
#  [ 930  204]]
#
# Confusion matrix on test data
# [[2699   11]
#  [ 423   63]]
# ----------------------------------------------------
#
# AUC: 0.947

# %%
# predict probabilities
plt.title("ROC Curve for test set of Tuned Bagging")
probs = model_bag_best.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=20)
# Out:
# AUC: 0.908

# %% [markdown]
# # Tuning Ada Boost

# %%
param_grid = {'algorithm' : ['SAMME', 'SAMME.R'], 'n_estimators' : [40,50,60] }
gs = GridSearchCV(model_adb,param_grid,cv=10)
gs.fit(X_train, y_train)
gs.best_params_
# Out:
# {'algorithm': 'SAMME.R', 'n_estimators': 60}

# %%
model_adb_best = AdaBoostClassifier(algorithm='SAMME.R',n_estimators=60, random_state=1)
model_adb_best.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=60, random_state=1)

# %%
# Predicting on Training and Test dataset
ytrain_predict = model_adb_best.predict(X_train)
ytest_predict = model_adb_best.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_adb_best.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_adb_best.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Tuned Ada Boosting")
probs = model_adb_best.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.8792918454935622
# Accuracy of the model on Testing data :  0.8679599499374218
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      6322
#            1       0.72      0.34      0.46      1134
#
#     accuracy                           0.88      7456
#    macro avg       0.81      0.66      0.69      7456
# weighted avg       0.87      0.88      0.86      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.93      2710
#            1       0.65      0.29      0.40       486
#
#     accuracy                           0.87      3196
#    macro avg       0.77      0.63      0.66      3196
# weighted avg       0.85      0.87      0.85      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6176  146]
#  [ 754  380]]
#
# Confusion matrix on test data
# [[2634   76]
#  [ 346  140]]
# ----------------------------------------------------
#
# AUC: 0.856

# %%
# predict probabilities
plt.title("ROC Curve for test set of Tuned Ada Boosting")
probs = model_adb_best.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=20)
# Out:
# AUC: 0.826

# %% [markdown]
# # Tuned Gradient Boosting

# %%
param_grid = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 4],
}
gs = GridSearchCV(model_gb,param_grid,cv=10)
gs.fit(X_train, y_train)
gs.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 200}

# %%
model_gb_best = GradientBoostingClassifier(n_estimators= 200,learning_rate= 0.1, max_depth =4 ).fit(X_train, y_train)

# %%
# Predicting on Training and Test dataset
ytrain_predict = model_gb_best.predict(X_train)
ytest_predict = model_gb_best.predict(X_test)

# Accuracy score
print('Accuracy of the model on Training data : ', model_gb_best.score(X_train, y_train))
print('Accuracy of the model on Testing data : ', model_gb_best.score(X_test, y_test))
print("----------------------------------------------------\n")

# Classification Report on Training data
print("Classification Report on Train Data\n")
print(classification_report(y_train, ytrain_predict))

# Classification Report on Test data
print("Classification Report on Test Data\n")
print(classification_report(y_test, ytest_predict))
print("----------------------------------------------------\n")

# Confusion Matrix on train data
print('Confusion matrix on train data')
print(confusion_matrix(y_train, ytrain_predict))

# Confusion Matrix on test data
print('\nConfusion matrix on test data')
print(confusion_matrix(y_test, ytest_predict))
print("----------------------------------------------------\n")

# predict probabilities
plt.title("ROC Curve for training set of Tuned Gradient Boosting")
probs = model_gb_best.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_train.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
plt.rc('font',size=20)
# Out:
# Accuracy of the model on Training data :  0.98068669527897
# Accuracy of the model on Testing data :  0.9458698372966208
# ----------------------------------------------------
#
# Classification Report on Train Data
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6322
#            1       0.99      0.88      0.93      1134
#
#     accuracy                           0.98      7456
#    macro avg       0.99      0.94      0.96      7456
# weighted avg       0.98      0.98      0.98      7456
#
# Classification Report on Test Data
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      2710
#            1       0.95      0.68      0.79       486
#
#     accuracy                           0.95      3196
#    macro avg       0.95      0.84      0.88      3196
# weighted avg       0.95      0.95      0.94      3196
#
# ----------------------------------------------------
#
# Confusion matrix on train data
# [[6316    6]
#  [ 138  996]]
#
# Confusion matrix on test data
# [[2692   18]
#  [ 155  331]]
# ----------------------------------------------------
#
# AUC: 0.998

# %%
# predict probabilities
plt.title("ROC Curve for test set of Tuned Gradient Boosting")
probs = model_gb_best.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test.astype(int), probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
plt.rc('font',size=20)
# Out:
# AUC: 0.978

# %% [markdown]
# # Comparing the models

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Create a list of model names and their corresponding model instances
models = [
    ("Logistic Regression", model_log),
    ("LDA", model_lda),
    ("KNN", model_knn),
    ("Naive Bayes", model_nb),
    ("Decision Tree", model_dt),
    ("Random Forest", model_rf),
    ("Bagging for Random Forest", model_bag),
    ("Ada Boost", model_adb),
    ("Gradient Boost", model_gb),
    ("Tuned Logistic Regression", model_log_best),
    ("Tuned LDA", model_lda_best),
    ("Tuned KNN", model_knn_best),
    ("Tuned Random Forest", model_rf_best),
    ("Tuned Bagging", model_bag_best),
    ("Tuned Ada Boost", model_adb_best),
    ("Tuned Gradient Boost", model_gb_best)
]

# Create an empty DataFrame to store the results
results = pd.DataFrame(columns=["Model", "Train Accuracy", "Test Accuracy", "Train Precision", "Test Precision", 
                                "Train Recall", "Test Recall", "Train F1 Score", "Test F1 Score", "Train AUC", "Test AUC"])

for model_name, model in models:
    # Fit the model on the training data
    model.fit(X_train, y_train)
    
    # Predict on the training and test data
    train_predictions = model.predict(X_train)
    test_predictions = model.predict(X_test)
    
    # Calculate metrics for training data
    train_accuracy = accuracy_score(y_train, train_predictions)
    train_precision = precision_score(y_train, train_predictions)
    train_recall = recall_score(y_train, train_predictions)
    train_f1 = f1_score(y_train, train_predictions)
    
    # Calculate AUC for training data based on predicted probabilities
    train_probs = model.predict_proba(X_train)[:, 1]
    train_auc = roc_auc_score(y_train, train_probs)
    
    # Calculate metrics for test data
    test_accuracy = accuracy_score(y_test, test_predictions)
    test_precision = precision_score(y_test, test_predictions)
    test_recall = recall_score(y_test, test_predictions)
    test_f1 = f1_score(y_test, test_predictions)
    
    # Calculate AUC for test data based on predicted probabilities
    test_probs = model.predict_proba(X_test)[:, 1]
    test_auc = roc_auc_score(y_test, test_probs)
    
    # Append the results to the DataFrame
    results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
                              "Train Precision": train_precision, "Test Precision": test_precision,
                              "Train Recall": train_recall, "Test Recall": test_recall,
                              "Train F1 Score": train_f1, "Test F1 Score": test_f1,
                              "Train AUC": train_auc, "Test AUC": test_auc}, ignore_index=True)

# Display the results DataFrame
results
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\2433624457.py:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": train_accuracy, "Test Accuracy": test_accuracy,
#                         Model Train Accuracy Test Accuracy Train Precision  \
# 0         Logistic Regression       0.870574      0.869212        0.766562
# 1                         LDA       0.868562       0.87015        0.698454
# 2                         KNN       0.976127      0.951815        0.963178
# 3                 Naive Bayes       0.780177      0.779412        0.281006
# 4               Decision Tree            1.0      0.975907             1.0
# 5               Random Forest            1.0      0.973091             1.0
# 6   Bagging for Random Forest       0.994903      0.952441        0.999089
# 7                   Ada Boost       0.878621      0.867647        0.718929
# 8              Gradient Boost       0.910408      0.898936        0.933086
# 9   Tuned Logistic Regression       0.871513      0.868899        0.771605
# 10                  Tuned LDA       0.868562       0.87015        0.698454
# 11                  Tuned KNN            1.0      0.987484             1.0
# 12        Tuned Random Forest       0.886668      0.875469        0.947368
# 13              Tuned Bagging       0.873256      0.864205        0.931507
# 14            Tuned Ada Boost       0.879292       0.86796        0.722433
# 15       Tuned Gradient Boost       0.980687       0.94587        0.994012
#
#    Test Precision Train Recall Test Recall Train F1 Score Test F1 Score  \
# 0        0.736111     0.214286    0.218107       0.334941      0.336508
# 1        0.700565     0.238977    0.255144        0.35611      0.374057
# 2        0.925641     0.876543    0.742798       0.917821      0.824201
# 3        0.281437     0.285714    0.290123       0.283341      0.285714
# 4        0.932347          1.0    0.907407            1.0      0.919708
# 5        0.997512          1.0    0.825103            1.0      0.903153
# 6        0.997024     0.967372      0.6893       0.982975      0.815085
# 7        0.649289      0.33157    0.281893       0.453832      0.393113
# 8        0.875576     0.442681    0.390947       0.600478      0.540541
# 9        0.731034     0.220459    0.218107       0.342936      0.335975
# 10       0.700565     0.238977    0.255144        0.35611      0.374057
# 11       0.960744          1.0     0.95679            1.0      0.958763
# 12            0.9     0.269841    0.203704       0.420041      0.332215
# 13       0.851351     0.179894     0.12963       0.301552         0.225
# 14       0.648148     0.335097    0.288066       0.457831       0.39886
# 15       0.948424     0.878307     0.68107       0.932584      0.792814
#
#    Train AUC  Test AUC
# 0   0.789924   0.79853
# 1   0.785197  0.794985
# 2   0.995806  0.980855
# 3   0.718672  0.718715
# 4        1.0    0.9478
# 5        1.0  0.998297
# 6    0.99999  0.994851
# 7   0.851983  0.822888
# 8   0.943281  0.910711
# 9   0.789723  0.798543
# 10  0.785197  0.794985
# 11       1.0   0.97489
# 12   0.96215  0.921597
# 13  0.947274   0.90837
# 14  0.856014  0.826353
# 15   0.99816  0.977948

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import pandas as pd

# Create a list of model names and their corresponding model instances
models = [
    ("Logistic Regression", model_log),
    ("LDA", model_lda),
    ("KNN", model_knn),
    ("Naive Bayes", model_nb),
    ("Decision Tree", model_dt),
    ("Random Forest", model_rf),
    ("Bagging for Random Forest", model_bag),
    ("Ada Boost", model_adb),
    ("Gradient Boost", model_gb),
    ("Tuned Logistic Regression", model_log_best),
    ("Tuned LDA", model_lda_best),
    ("Tuned KNN", model_knn_best),
    ("Tuned Random Forest", model_rf_best),
    ("Tuned Bagging", model_bag_best),
    ("Tuned Ada Boost", model_adb_best),
    ("Tuned Gradient Boost", model_gb_best)
]

# Create an empty DataFrame to store the results
results = pd.DataFrame(columns=["Model", "Train Accuracy", "Test Accuracy", "Train Precision", "Test Precision", 
                                "Train Recall", "Test Recall", "Train F1 Score", "Test F1 Score", "Train AUC", "Test AUC"])

for model_name, model in models:
    # Fit the model on the training data
    model.fit(X_train, y_train)
    
    # Predict on the training and test data
    train_predictions = model.predict(X_train)
    test_predictions = model.predict(X_test)
    
    # Calculate metrics for training data
    train_accuracy = accuracy_score(y_train, train_predictions) * 100
    train_precision = precision_score(y_train, train_predictions) * 100
    train_recall = recall_score(y_train, train_predictions) * 100
    train_f1 = f1_score(y_train, train_predictions) * 100
    
    # Calculate AUC for training data based on predicted probabilities
    train_probs = model.predict_proba(X_train)[:, 1]
    train_auc = roc_auc_score(y_train, train_probs) * 100
    
    # Calculate metrics for test data
    test_accuracy = accuracy_score(y_test, test_predictions) * 100
    test_precision = precision_score(y_test, test_predictions) * 100
    test_recall = recall_score(y_test, test_predictions) * 100
    test_f1 = f1_score(y_test, test_predictions) * 100
    
    # Calculate AUC for test data based on predicted probabilities
    test_probs = model.predict_proba(X_test)[:, 1]
    test_auc = roc_auc_score(y_test, test_probs) * 100
    
    # Append the results to the DataFrame
    results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
                              "Test Accuracy": f"{test_accuracy:.2f}%",
                              "Train Precision": f"{train_precision:.2f}%",
                              "Test Precision": f"{test_precision:.2f}%",
                              "Train Recall": f"{train_recall:.2f}%",
                              "Test Recall": f"{test_recall:.2f}%",
                              "Train F1 Score": f"{train_f1:.2f}%",
                              "Test F1 Score": f"{test_f1:.2f}%",
                              "Train AUC": f"{train_auc:.2f}%",
                              "Test AUC": f"{test_auc:.2f}%"}, ignore_index=True)

# Display the results DataFrame
results
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13260\857486192.py:57: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({"Model": model_name, "Train Accuracy": f"{train_accuracy:.2f}%",
#                         Model Train Accuracy Test Accuracy Train Precision  \
# 0         Logistic Regression         87.06%        86.92%          76.66%
# 1                         LDA         86.86%        87.02%          69.85%
# 2                         KNN         97.61%        95.18%          96.32%
# 3                 Naive Bayes         78.02%        77.94%          28.10%
# 4               Decision Tree        100.00%        97.43%         100.00%
# 5               Random Forest        100.00%        97.31%         100.00%
# 6   Bagging for Random Forest         99.49%        95.24%          99.91%
# 7                   Ada Boost         87.86%        86.76%          71.89%
# 8              Gradient Boost         91.04%        89.89%          93.31%
# 9   Tuned Logistic Regression         87.15%        86.89%          77.16%
# 10                  Tuned LDA         86.86%        87.02%          69.85%
# 11                  Tuned KNN        100.00%        98.75%         100.00%
# 12        Tuned Random Forest         88.60%        87.33%          95.51%
# 13              Tuned Bagging         87.33%        86.42%          93.15%
# 14            Tuned Ada Boost         87.93%        86.80%          72.24%
# 15       Tuned Gradient Boost         98.07%        94.59%          99.40%
#
#    Test Precision Train Recall Test Recall Train F1 Score Test F1 Score  \
# 0          73.61%       21.43%      21.81%         33.49%        33.65%
# 1          70.06%       23.90%      25.51%         35.61%        37.41%
# 2          92.56%       87.65%      74.28%         91.78%        82.42%
# 3          28.14%       28.57%      29.01%         28.33%        28.57%
# 4          92.08%      100.00%      90.95%        100.00%        91.51%
# 5          99.75%      100.00%      82.51%        100.00%        90.32%
# 6          99.70%       96.74%      68.93%         98.30%        81.51%
# 7          64.93%       33.16%      28.19%         45.38%        39.31%
# 8          87.56%       44.27%      39.09%         60.05%        54.05%
# 9          73.10%       22.05%      21.81%         34.29%        33.60%
# 10         70.06%       23.90%      25.51%         35.61%        37.41%
# 11         96.07%      100.00%      95.68%        100.00%        95.88%
# 12         90.10%       26.28%      18.72%         41.22%        31.01%
# 13         85.14%       17.99%      12.96%         30.16%        22.50%
# 14         64.81%       33.51%      28.81%         45.78%        39.89%
# 15         94.84%       87.83%      68.11%         93.26%        79.28%
#
#    Train AUC Test AUC
# 0     78.99%   79.85%
# 1     78.52%   79.50%
# 2     99.58%   98.09%
# 3     71.87%   71.87%
# 4    100.00%   94.77%
# 5    100.00%   99.83%
# 6    100.00%   99.49%
# 7     85.20%   82.29%
# 8     94.33%   91.07%
# 9     78.97%   79.85%
# 10    78.52%   79.50%
# 11   100.00%   97.49%
# 12    96.65%   92.69%
# 13    94.73%   90.84%
# 14    85.60%   82.64%
# 15    99.82%   97.78%
